# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/skoltech-nlp/russe_detox_2022/main/data/input/train.tsv
# !wget https://raw.githubusercontent.com/skoltech-nlp/russe_detox_2022/main/data/input/dev.tsv
# Out:
# --2023-04-22 15:38:57--  https://raw.githubusercontent.com/skoltech-nlp/russe_detox_2022/main/data/input/train.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1902888 (1.8M) [text/plain]
# Saving to: ‘train.tsv’
#
# train.tsv           100%[===================>]   1.81M  --.-KB/s    in 0.01s
#
# 2023-04-22 15:38:57 (153 MB/s) - ‘train.tsv’ saved [1902888/1902888]
#
# --2023-04-22 15:38:57--  https://raw.githubusercontent.com/skoltech-nlp/russe_detox_2022/main/data/input/dev.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
train = pd.read_csv("train.tsv", sep="\t")
train = train.drop(columns=['index'])
dev = pd.read_csv("dev.tsv", sep="\t")
train
# Out:
#                                           toxic_comment  \
# 0     и,чё,блядь где этот херой был до этого со свои...
# 1                        О, а есть деанон этого петуха?
# 2      херну всякую пишут,из-за этого лайка.долбоебизм.
# 3                     из за таких пидоров мы и страдаем
# 4                       гондон путинский он а не артист
# ...                                                 ...
# 6943  Блядь, пусть его уже закроют до конца его дней...
# 6944                   твоя химия это тотальный пиздец(
# 6945          меня изнасиловали, мудилка, а тебе пох(((
# 6946  когда наплоюсь на пидораса и маньяка похож((((...
# 6947         ПАШАСЛАВА МУДЕНЬ КИНУЛ БЕДНЫХ БАБ((9990909
#
#                                        neutral_comment1  \
# 0     Ну и где этот герой был,со своими доказательст...
# 1                                      О, а есть деанон
# 2                Чушь всякую пишут, из- за этого лайка.
# 3                из за таких плохих людей мы и страдаем
# ...

# %%
train_df = pd.DataFrame()
train_df['text'] = pd.concat([train['toxic_comment'], train['neutral_comment1']])
train_df['label'] = pd.concat([pd.Series(['toxic'] * len(train)), pd.Series(['neutral'] * len(train))])
train_df = train_df.reset_index(drop=True)
train_df
# Out:
#                                                     text    label
# 0      и,чё,блядь где этот херой был до этого со свои...    toxic
# 1                         О, а есть деанон этого петуха?    toxic
# 2       херну всякую пишут,из-за этого лайка.долбоебизм.    toxic
# 3                      из за таких пидоров мы и страдаем    toxic
# 4                        гондон путинский он а не артист    toxic
# ...                                                  ...      ...
# 13891  Пусть его уже закроют до конца его дней, он же...  neutral
# 13892                     твоя химия - это просто кошмар  neutral
# 13893             меня изнасиловали,а тебе всё равно (((  neutral
# 13894                Когда напьюсь - на маньяка похож...  neutral
# 13895                     Паша слава кинул бедных женщин  neutral
#
# [13896 rows x 2 columns]

# %%
dev_df = pd.DataFrame()
dev_df['text'] = pd.concat([dev['toxic_comment'], dev['neutral_comment1']])
dev_df['label'] = pd.concat([pd.Series(['toxic'] * len(dev)), pd.Series(['neutral'] * len(dev))])
dev_df = dev_df.reset_index(drop=True)
dev_df
# Out:
#                                                    text    label
# 0     пиздеж! температуры горения хватит чтобы её ра...    toxic
# 1              а ты чмо там был.ты вообще служил.гандон    toxic
# 2                   пиздабол ---- а сам где кормишься ?    toxic
# 3     этому сайту я давно не доверяю, пишут разную х...    toxic
# 4     у меня сегодня подобный звонок был. достали го...    toxic
# ...                                                 ...      ...
# 1595       киргиз украл, она сбежала, так он ее зарезал  neutral
# 1596  Это не от того что желающих работать нет а от ...  neutral
# 1597  Если хочешь показать себя , купи кольцо, цветы...  neutral
# 1598  такому плохому  человеку ничего нельзя доверит...  neutral
# 1599  Самий нехороший, здесь бартамео он уйдет и всё...  neutral
#
# [1600 rows x 2 columns]

# %%
train_df.to_csv('classification_train.csv', index=False)
dev_df.to_csv('classification_dev.csv', index=False)
